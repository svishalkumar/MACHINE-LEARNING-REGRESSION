# %% [markdown]
# # Iphone Purchases are getting increased day by day and many stores want to predict whether a customer will purchase an iPhone

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
def read_data():
    data = pd.read_csv("D:\\Data_set\\76 5\\KNN Assignment\iphone_purchase_records.csv")
    return data
data= read_data()

# %%
data.head()
# Out:
#    Gender  Age  Salary  Purchase Iphone
# 0    Male   19   19000                0
# 1    Male   35   20000                0
# 2  Female   26   43000                0
# 3  Female   27   57000                0
# 4    Male   19   76000                0

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           400 non-null    object
#  1   Age              400 non-null    int64
#  2   Salary           400 non-null    int64
#  3   Purchase Iphone  400 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 12.6+ KB
# None

# %%
print(data.describe())
# Out:
#               Age         Salary  Purchase Iphone
# count  400.000000     400.000000       400.000000
# mean    37.655000   69742.500000         0.357500
# std     10.482877   34096.960282         0.479864
# min     18.000000   15000.000000         0.000000
# 25%     29.750000   43000.000000         0.000000
# 50%     37.000000   70000.000000         0.000000
# 75%     46.000000   88000.000000         1.000000
# max     60.000000  150000.000000         1.000000

# %%
print(data.isnull().sum())
# Out:
# Gender             0
# Age                0
# Salary             0
# Purchase Iphone    0
# dtype: int64

# %%
print(data.duplicated().sum())
# Out:
# 20

# %%
data.drop_duplicates(inplace=True)

# %%
lb= LabelEncoder()

# %%
data['Gender'] = lb.fit_transform(data['Gender'])

# %%
data.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Salary'}>,
#         <Axes: title={'center': 'Purchase Iphone'}>]], dtype=object)

# %%
sns.pairplot(data,hue='Purchase Iphone')

# %%
x = data[['Salary','Age']]
y = data['Purchase Iphone']

x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.1,random_state=1234)

# %%
model = DecisionTreeClassifier()

# %%
model_train = model.fit(x_train,y_train)

# %%
round(accuracy_score(y_test,pred)*100,2)

confusion_matrix(y_test,pred)
# Out:
# 88.3

# %%
pred = model_train.predict(x_test)

# %%
model_train.feature_importances_
# Out:
# array([0.56018519, 0.43981481])

# %%
feat_impt = pd.Series(model_train.feature_importances_,index=x.columns)

# %%
feat_impt.plot(kind='bar')
# Out:
# <Axes: >

# %%
### Using a another Algorithm

# %%
from sklearn.svm import SVC

# %%
modl = SVC()

# %%
modl_train = modl.fit(x_train,y_train)

# %%
predd = modl_train.predict(x_test)

# %%
accuracy_score(y_test,predd)
# Out:
# 0.7573099415204678
